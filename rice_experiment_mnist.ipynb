# %% [markdown]
# <a href="https://colab.research.google.com/github/gbachu/rice-experiment-mnist.ipynb/blob/main/rice_experiment_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spikingjelly
# Out:
# Collecting spikingjelly
#   Downloading spikingjelly-0.0.0.0.14-py3-none-any.whl (437 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.6/437.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (2.3.0+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (4.66.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (0.18.0+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from spikingjelly) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spikingjelly) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->spikingjelly)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->spikingjelly)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->spikingjelly)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->spikingjelly)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->spikingjelly)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->spikingjelly)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->spikingjelly)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->spikingjelly)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->spikingjelly)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->spikingjelly)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->spikingjelly)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->spikingjelly) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->spikingjelly)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->spikingjelly) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->spikingjelly) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->spikingjelly) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, spikingjelly
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 spikingjelly-0.0.0.0.14

# %% [markdown]
# Quadratic & SpikingJellyQuadratic Classes

# %%
import torch
from torch import func
from torch import nn
import torch.nn.functional as F
from torch import Tensor

# Based on nn.Linear
# https://pytorch.org/docs/stable/_modules/torch/nn/modules/linear.html#Linear

class Quadratic(nn.Module):

    __constants__ = ['in_features', 'out_features']
    in_features: int
    out_features: int
    fc_1: nn.Linear
    fc_2: nn.Linear

    def __init__(self, in_features: int, out_features: int,
                 bias_1: bool = True, bias_2: bool = True,
                 device=None, dtype=None) -> None:
        factory_kwargs = {'device': device, 'dtype': dtype}
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.fc_1 = nn.Linear(in_features, out_features, bias_1)
        self.fc_2 = nn.Linear(in_features, out_features, bias_2)

    def reset_parameters(self) -> None:
        self.fc_1.reset_parameters()
        self.fc_2.reset_parameters()

    def forward(self, input: Tensor) -> Tensor:
        return self.fc_1(input) * (1 + self.fc_2(input))

    def extra_repr(self) -> str:
        return 'in_features={}, out_features={}, bias_1st={}, bias_2nd={}'.format(
            self.in_features, self.out_features,
            self.fc_1.bias is not None, self.fc_2.bias is not None
        )

# %%
import logging

import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from spikingjelly.activation_based import base, functional
from torch import Tensor
from torch.nn.common_types import _size_any_t, _size_1_t, _size_2_t, _size_3_t
from typing import Optional, List, Tuple, Union
from typing import Callable
from torch.nn.modules.batchnorm import _BatchNorm

# Based on SpikingJelly's layer.Linear
class SpikingJellyQuadratic(Quadratic, base.StepModule):
    def __init__(self, in_features: int, out_features: int, bias: bool = True, step_mode='s') -> None:
        super().__init__(in_features, out_features, bias)
        self.step_mode = step_mode

# %% [markdown]
# Running Model

# %%
import os
import time
import argparse
import sys
import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
from torch.cuda import amp
from torch.utils.tensorboard import SummaryWriter
import torchvision
import matplotlib.pyplot as plt # Addded for "Plotting"
import numpy as np

from spikingjelly.activation_based import neuron, encoding, functional, surrogate, layer



class SNN(nn.Module):
    def __init__(self, tau):
        super().__init__()

        self.layer = nn.Sequential(
            layer.Flatten(),
            SpikingJellyQuadratic(28 * 28, 10, bias=False), # Replaced layer.Linear with SpikingJellyQuadratic
            neuron.LIFNode(tau=tau, surrogate_function=surrogate.ATan()),
            )

    def forward(self, x: torch.Tensor):
        return self.layer(x)

# Dictionary to Replace Parser
args = {
    "T": 10, # 10
    "device": 'cuda:0',
    "b": 64,
    "epochs": 100, # 100
    "j": 4,
    "data_dir": './datasets/MNIST',
    "out_dir": './logs',
    "amp": 'store_true',
    "opt": 'adam',
    "momentum": 0.9,
    "lr": 1e-3,
    "tau": 2.0
}

def main(params=args):

    #From parser
    print(args)
    net = SNN(tau=args.get("tau"))
    print(net)
    net.to(args.get("device"))

    # For Plotting
    x_values = np.array([])
    y_values = np.array([])


    train_dataset = torchvision.datasets.MNIST(
        root=str(args.get("data_dir")),
        train=True,
        transform=torchvision.transforms.ToTensor(),
        download=True
    )

    test_dataset = torchvision.datasets.MNIST(
        root=str(args.get("data_dir")),
        train=False,
        transform=torchvision.transforms.ToTensor(),
        download=True
    )

    train_data_loader = data.DataLoader(
        dataset=train_dataset,
        batch_size=args.get("b"),
        shuffle=True,
        drop_last=True,
        num_workers=args.get("j"),
        pin_memory=True
    )

    test_data_loader = data.DataLoader(
        dataset=test_dataset,
        batch_size=args.get("b"),
        shuffle=False,
        drop_last=False,
        num_workers=args.get("j"),
        pin_memory=True
    )

    scaler = None
    if args.get("amp"):
        scaler = amp.GradScaler()

    start_epoch = 0
    max_test_acc = -1

    optimizer = None
    if args.get("opt") == 'sgd':
        optimizer = torch.optim.SGD(net.parameters(), lr=args.get("lr"), momentum=args.get("momentum"))
    elif args.get("opt") == 'adam':
        optimizer = torch.optim.Adam(net.parameters(), lr=args.get("lr"))
    else:
        raise NotImplementedError(args.get("opt"))

    out_dir = os.path.join(str(args.get("out_dir")), f'T{str(args.get("T"))}_b{str(args.get("b"))}_{str(args.get("opt"))}_lr{str(args.get("lr"))}')
    out_dir += '__' + datetime.datetime.today().strftime('%Y-%m-%d-%H-%M')

    if args.get("amp"):
        out_dir += '_amp'

    os.makedirs(out_dir, exist_ok=True)

    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))

    writer = SummaryWriter(out_dir, purge_step=start_epoch)
    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))
        args_txt.write('\n')
        args_txt.write(' '.join(sys.argv))

    encoder = encoding.PoissonEncoder()

    for epoch in range(start_epoch, args.get("epochs")):
        start_time = time.time()
        net.train()
        train_loss = 0
        train_acc = 0
        train_samples = 0
        for img, label in train_data_loader:
            optimizer.zero_grad()
            img = img.to(args.get("device"))
            label = label.to(args.get("device"))
            label_onehot = F.one_hot(label, 10).float()

            if scaler is not None:
                with amp.autocast():
                    out_fr = 0.
                    for t in range(args.get("T")):
                        encoded_img = encoder(img)
                        out_fr += net(encoded_img)
                    out_fr = out_fr / args.get("T")
                    loss = F.mse_loss(out_fr, label_onehot)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                out_fr = 0.
                for t in range(args.T):
                    encoded_img = encoder(img)
                    out_fr += net(encoded_img)
                out_fr = out_fr / args.T
                loss = F.mse_loss(out_fr, label_onehot)
                loss.backward()
                optimizer.step()

            train_samples += label.numel()
            train_loss += loss.item() * label.numel()
            train_acc += (out_fr.argmax(1) == label).float().sum().item()

            functional.reset_net(net)

        train_time = time.time()
        train_speed = train_samples / (train_time - start_time)
        train_loss /= train_samples
        train_acc /= train_samples

        writer.add_scalar('train_loss', train_loss, epoch)
        writer.add_scalar('train_acc', train_acc, epoch)

        net.eval()
        test_loss = 0
        test_acc = 0
        test_samples = 0
        with torch.no_grad():
            for img, label in test_data_loader:
                img = img.to(args.get("device"))
                label = label.to(args.get("device"))
                label_onehot = F.one_hot(label, 10).float()
                out_fr = 0.
                for t in range(args.get("T")):
                    encoded_img = encoder(img)
                    out_fr += net(encoded_img)
                out_fr = out_fr / args.get("T")
                loss = F.mse_loss(out_fr, label_onehot)

                test_samples += label.numel()
                test_loss += loss.item() * label.numel()
                test_acc += (out_fr.argmax(1) == label).float().sum().item()
                functional.reset_net(net)
        test_time = time.time()
        test_speed = test_samples / (test_time - train_time)
        test_loss /= test_samples
        test_acc /= test_samples
        writer.add_scalar('test_loss', test_loss, epoch)
        writer.add_scalar('test_acc', test_acc, epoch)

        save_max = False
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            save_max = True

        checkpoint = {
            'net': net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': epoch,
            'max_test_acc': max_test_acc
        }

        if save_max:
            torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_max.pth'))

        torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_latest.pth'))

        print(args)
        print(out_dir)
        print(f'epoch ={epoch}, train_loss ={train_loss: .4f}, train_acc ={train_acc: .4f}, test_loss ={test_loss: .4f}, test_acc ={test_acc: .4f}, max_test_acc ={max_test_acc: .4f}')
        print(f'train speed ={train_speed: .4f} images/s, test speed ={test_speed: .4f} images/s')
        print(f'escape time = {(datetime.datetime.now() + datetime.timedelta(seconds=(time.time() - start_time) * (args.get("epochs") - epoch))).strftime("%Y-%m-%d %H:%M:%S")}\n')

        # For Plotting
        x_values = np.append(x_values, epoch)
        y_values = np.append(y_values, max_test_acc)


    net.eval()
    output_layer = net.layer[-1]
    output_layer.v_seq = []
    output_layer.s_seq = []
    def save_hook(m, x, y):
        m.v_seq.append(m.v.unsqueeze(0))
        m.s_seq.append(y.unsqueeze(0))

    output_layer.register_forward_hook(save_hook)


    with torch.no_grad():
        img, label = test_dataset[0]
        img = img.to(args.get("device"))
        out_fr = 0.
        for t in range(int(args.get("T"))):
            encoded_img = encoder(img)
            out_fr += net(encoded_img)
        out_spikes_counter_frequency = (out_fr / args.get("T")).cpu().numpy()
        print(f'Firing rate: {out_spikes_counter_frequency}')

        output_layer.v_seq = torch.cat(output_layer.v_seq)
        output_layer.s_seq = torch.cat(output_layer.s_seq)
        v_t_array = output_layer.v_seq.cpu().numpy().squeeze()  # v_t_array[i][j]
        np.save("v_t_array.npy",v_t_array)
        s_t_array = output_layer.s_seq.cpu().numpy().squeeze()  # s_t_array[i][j]
        np.save("s_t_array.npy",s_t_array)

    # Plotting
    print("X-Values: Epochs ", x_values)
    print("Y-Values: Max Test Accuracy ", y_values)
    plt.xlabel("Epochs")
    plt.ylabel("Max Test Accuracy")
    plt.plot(x_values, y_values)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# SNN(
#   (layer): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1, step_mode=s)
#     (1): SpikingJellyQuadratic(
#       in_features=784, out_features=10, bias_1st=False, bias_2nd=True
#       (fc_1): Linear(in_features=784, out_features=10, bias=False)
#       (fc_2): Linear(in_features=784, out_features=10, bias=True)
#     )
#     (2): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=False, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#   )
# )
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =0, train_loss = 0.0222, train_acc = 0.8815, test_loss = 0.0160, test_acc = 0.9175, max_test_acc = 0.9175
# train speed = 2897.9529 images/s, test speed = 3218.2892 images/s
# escape time = 2024-06-13 00:41:25
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =1, train_loss = 0.0155, train_acc = 0.9210, test_loss = 0.0141, test_acc = 0.9252, max_test_acc = 0.9252
# train speed = 3033.9477 images/s, test speed = 5209.4885 images/s
# escape time = 2024-06-13 00:37:53
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =2, train_loss = 0.0141, train_acc = 0.9280, test_loss = 0.0134, test_acc = 0.9320, max_test_acc = 0.9320
# train speed = 2904.9824 images/s, test speed = 4525.7007 images/s
# escape time = 2024-06-13 00:39:48
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =3, train_loss = 0.0131, train_acc = 0.9334, test_loss = 0.0135, test_acc = 0.9306, max_test_acc = 0.9320
# train speed = 3067.7326 images/s, test speed = 4991.5368 images/s
# escape time = 2024-06-13 00:37:41
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =4, train_loss = 0.0126, train_acc = 0.9355, test_loss = 0.0130, test_acc = 0.9313, max_test_acc = 0.9320
# train speed = 2841.7177 images/s, test speed = 4943.0075 images/s
# escape time = 2024-06-13 00:40:13
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =5, train_loss = 0.0122, train_acc = 0.9380, test_loss = 0.0125, test_acc = 0.9343, max_test_acc = 0.9343
# train speed = 3009.3469 images/s, test speed = 4888.8559 images/s
# escape time = 2024-06-13 00:38:23
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =6, train_loss = 0.0119, train_acc = 0.9391, test_loss = 0.0127, test_acc = 0.9335, max_test_acc = 0.9343
# train speed = 2519.9385 images/s, test speed = 4623.9952 images/s
# escape time = 2024-06-13 00:44:42
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =7, train_loss = 0.0117, train_acc = 0.9409, test_loss = 0.0124, test_acc = 0.9318, max_test_acc = 0.9343
# train speed = 3048.4642 images/s, test speed = 5088.1907 images/s
# escape time = 2024-06-13 00:37:55
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =8, train_loss = 0.0115, train_acc = 0.9411, test_loss = 0.0123, test_acc = 0.9366, max_test_acc = 0.9366
# train speed = 2838.6344 images/s, test speed = 4917.7688 images/s
# escape time = 2024-06-13 00:40:17
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =9, train_loss = 0.0114, train_acc = 0.9428, test_loss = 0.0123, test_acc = 0.9393, max_test_acc = 0.9393
# train speed = 3066.2518 images/s, test speed = 5038.2974 images/s
# escape time = 2024-06-13 00:37:48
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =10, train_loss = 0.0113, train_acc = 0.9428, test_loss = 0.0126, test_acc = 0.9327, max_test_acc = 0.9393
# train speed = 2777.0656 images/s, test speed = 4963.2305 images/s
# escape time = 2024-06-13 00:40:56
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =11, train_loss = 0.0111, train_acc = 0.9435, test_loss = 0.0123, test_acc = 0.9363, max_test_acc = 0.9393
# train speed = 3077.1258 images/s, test speed = 5157.9536 images/s
# escape time = 2024-06-13 00:37:40
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =12, train_loss = 0.0111, train_acc = 0.9444, test_loss = 0.0119, test_acc = 0.9368, max_test_acc = 0.9393
# train speed = 2563.6493 images/s, test speed = 4996.4656 images/s
# escape time = 2024-06-13 00:43:33
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =13, train_loss = 0.0109, train_acc = 0.9450, test_loss = 0.0124, test_acc = 0.9343, max_test_acc = 0.9393
# train speed = 3045.9865 images/s, test speed = 5103.6822 images/s
# escape time = 2024-06-13 00:38:03
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =14, train_loss = 0.0109, train_acc = 0.9443, test_loss = 0.0124, test_acc = 0.9353, max_test_acc = 0.9393
# train speed = 2807.3262 images/s, test speed = 5068.9332 images/s
# escape time = 2024-06-13 00:40:30
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =15, train_loss = 0.0109, train_acc = 0.9451, test_loss = 0.0119, test_acc = 0.9374, max_test_acc = 0.9393
# train speed = 3077.5024 images/s, test speed = 4942.4617 images/s
# escape time = 2024-06-13 00:37:53
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =16, train_loss = 0.0108, train_acc = 0.9455, test_loss = 0.0125, test_acc = 0.9340, max_test_acc = 0.9393
# train speed = 2813.5285 images/s, test speed = 5175.3482 images/s
# escape time = 2024-06-13 00:40:20
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =17, train_loss = 0.0107, train_acc = 0.9463, test_loss = 0.0121, test_acc = 0.9377, max_test_acc = 0.9393
# train speed = 3021.5317 images/s, test speed = 4357.2309 images/s
# escape time = 2024-06-13 00:38:48
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =18, train_loss = 0.0107, train_acc = 0.9452, test_loss = 0.0124, test_acc = 0.9352, max_test_acc = 0.9393
# train speed = 2773.2954 images/s, test speed = 4925.2078 images/s
# escape time = 2024-06-13 00:40:53
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =19, train_loss = 0.0106, train_acc = 0.9466, test_loss = 0.0122, test_acc = 0.9386, max_test_acc = 0.9393
# train speed = 2780.6188 images/s, test speed = 3182.3351 images/s
# escape time = 2024-06-13 00:42:20
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =20, train_loss = 0.0106, train_acc = 0.9461, test_loss = 0.0121, test_acc = 0.9392, max_test_acc = 0.9393
# train speed = 2989.2449 images/s, test speed = 5051.2300 images/s
# escape time = 2024-06-13 00:38:44
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =21, train_loss = 0.0106, train_acc = 0.9465, test_loss = 0.0123, test_acc = 0.9342, max_test_acc = 0.9393
# train speed = 2964.8273 images/s, test speed = 3049.1074 images/s
# escape time = 2024-06-13 00:40:41
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =22, train_loss = 0.0106, train_acc = 0.9470, test_loss = 0.0121, test_acc = 0.9351, max_test_acc = 0.9393
# train speed = 2996.1590 images/s, test speed = 5036.6016 images/s
# escape time = 2024-06-13 00:38:42
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =23, train_loss = 0.0105, train_acc = 0.9476, test_loss = 0.0121, test_acc = 0.9364, max_test_acc = 0.9393
# train speed = 3021.5125 images/s, test speed = 3167.2098 images/s
# escape time = 2024-06-13 00:40:00
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =24, train_loss = 0.0104, train_acc = 0.9475, test_loss = 0.0118, test_acc = 0.9380, max_test_acc = 0.9393
# train speed = 3007.8425 images/s, test speed = 4968.7627 images/s
# escape time = 2024-06-13 00:38:39
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =25, train_loss = 0.0104, train_acc = 0.9470, test_loss = 0.0118, test_acc = 0.9382, max_test_acc = 0.9393
# train speed = 2694.3630 images/s, test speed = 4285.2717 images/s
# escape time = 2024-06-13 00:42:00
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =26, train_loss = 0.0104, train_acc = 0.9476, test_loss = 0.0121, test_acc = 0.9382, max_test_acc = 0.9393
# train speed = 3014.5656 images/s, test speed = 5136.1722 images/s
# escape time = 2024-06-13 00:38:33
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =27, train_loss = 0.0104, train_acc = 0.9476, test_loss = 0.0121, test_acc = 0.9377, max_test_acc = 0.9393
# train speed = 2843.3559 images/s, test speed = 4915.9560 images/s
# escape time = 2024-06-13 00:40:08
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =28, train_loss = 0.0103, train_acc = 0.9478, test_loss = 0.0120, test_acc = 0.9380, max_test_acc = 0.9393
# train speed = 3023.0027 images/s, test speed = 5207.2546 images/s
# escape time = 2024-06-13 00:38:29
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =29, train_loss = 0.0103, train_acc = 0.9484, test_loss = 0.0121, test_acc = 0.9381, max_test_acc = 0.9393
# train speed = 2626.4937 images/s, test speed = 4846.8337 images/s
# escape time = 2024-06-13 00:42:15
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =30, train_loss = 0.0103, train_acc = 0.9477, test_loss = 0.0118, test_acc = 0.9383, max_test_acc = 0.9393
# train speed = 3030.2768 images/s, test speed = 5120.7564 images/s
# escape time = 2024-06-13 00:38:31
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =31, train_loss = 0.0103, train_acc = 0.9482, test_loss = 0.0123, test_acc = 0.9360, max_test_acc = 0.9393
# train speed = 2839.9025 images/s, test speed = 5151.1167 images/s
# escape time = 2024-06-13 00:40:03
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =32, train_loss = 0.0102, train_acc = 0.9491, test_loss = 0.0117, test_acc = 0.9385, max_test_acc = 0.9393
# train speed = 2712.8492 images/s, test speed = 4973.1530 images/s
# escape time = 2024-06-13 00:41:16
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =33, train_loss = 0.0102, train_acc = 0.9484, test_loss = 0.0125, test_acc = 0.9384, max_test_acc = 0.9393
# train speed = 2800.9499 images/s, test speed = 4796.6561 images/s
# escape time = 2024-06-13 00:40:34
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =34, train_loss = 0.0102, train_acc = 0.9481, test_loss = 0.0118, test_acc = 0.9381, max_test_acc = 0.9393
# train speed = 3058.7436 images/s, test speed = 4924.5561 images/s
# escape time = 2024-06-13 00:38:29
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =35, train_loss = 0.0102, train_acc = 0.9488, test_loss = 0.0120, test_acc = 0.9371, max_test_acc = 0.9393
# train speed = 2827.9255 images/s, test speed = 4731.5769 images/s
# escape time = 2024-06-13 00:40:20
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =36, train_loss = 0.0101, train_acc = 0.9489, test_loss = 0.0121, test_acc = 0.9347, max_test_acc = 0.9393
# train speed = 3037.1524 images/s, test speed = 4989.2128 images/s
# escape time = 2024-06-13 00:38:38
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =37, train_loss = 0.0101, train_acc = 0.9490, test_loss = 0.0121, test_acc = 0.9348, max_test_acc = 0.9393
# train speed = 2835.4431 images/s, test speed = 4931.9629 images/s
# escape time = 2024-06-13 00:40:10
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =38, train_loss = 0.0101, train_acc = 0.9487, test_loss = 0.0121, test_acc = 0.9392, max_test_acc = 0.9393
# train speed = 2948.1493 images/s, test speed = 5165.0269 images/s
# escape time = 2024-06-13 00:39:13
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =39, train_loss = 0.0101, train_acc = 0.9494, test_loss = 0.0120, test_acc = 0.9360, max_test_acc = 0.9393
# train speed = 2534.8175 images/s, test speed = 5168.0989 images/s
# escape time = 2024-06-13 00:42:38
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =40, train_loss = 0.0101, train_acc = 0.9491, test_loss = 0.0120, test_acc = 0.9361, max_test_acc = 0.9393
# train speed = 3052.2304 images/s, test speed = 4980.7263 images/s
# escape time = 2024-06-13 00:38:39
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =41, train_loss = 0.0101, train_acc = 0.9493, test_loss = 0.0121, test_acc = 0.9362, max_test_acc = 0.9393
# train speed = 2806.7265 images/s, test speed = 5142.6926 images/s
# escape time = 2024-06-13 00:40:18
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =42, train_loss = 0.0101, train_acc = 0.9491, test_loss = 0.0122, test_acc = 0.9354, max_test_acc = 0.9393
# train speed = 3049.7005 images/s, test speed = 4672.8761 images/s
# escape time = 2024-06-13 00:38:49
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =43, train_loss = 0.0101, train_acc = 0.9494, test_loss = 0.0119, test_acc = 0.9371, max_test_acc = 0.9393
# train speed = 2808.6197 images/s, test speed = 5146.2937 images/s
# escape time = 2024-06-13 00:40:15
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =44, train_loss = 0.0099, train_acc = 0.9497, test_loss = 0.0121, test_acc = 0.9341, max_test_acc = 0.9393
# train speed = 2970.0983 images/s, test speed = 5080.6479 images/s
# escape time = 2024-06-13 00:39:10
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =45, train_loss = 0.0100, train_acc = 0.9495, test_loss = 0.0120, test_acc = 0.9355, max_test_acc = 0.9393
# train speed = 2778.4217 images/s, test speed = 3076.6358 images/s
# escape time = 2024-06-13 00:41:40
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =46, train_loss = 0.0100, train_acc = 0.9497, test_loss = 0.0122, test_acc = 0.9362, max_test_acc = 0.9393
# train speed = 2792.3896 images/s, test speed = 3118.8027 images/s
# escape time = 2024-06-13 00:41:32
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =47, train_loss = 0.0100, train_acc = 0.9489, test_loss = 0.0120, test_acc = 0.9377, max_test_acc = 0.9393
# train speed = 3006.3677 images/s, test speed = 4650.6242 images/s
# escape time = 2024-06-13 00:39:12
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =48, train_loss = 0.0099, train_acc = 0.9505, test_loss = 0.0120, test_acc = 0.9369, max_test_acc = 0.9393
# train speed = 2909.1906 images/s, test speed = 4829.4206 images/s
# escape time = 2024-06-13 00:39:43
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =49, train_loss = 0.0099, train_acc = 0.9502, test_loss = 0.0120, test_acc = 0.9384, max_test_acc = 0.9393
# train speed = 3019.8439 images/s, test speed = 4896.2506 images/s
# escape time = 2024-06-13 00:39:03
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =50, train_loss = 0.0099, train_acc = 0.9499, test_loss = 0.0120, test_acc = 0.9368, max_test_acc = 0.9393
# train speed = 2811.8286 images/s, test speed = 4914.6450 images/s
# escape time = 2024-06-13 00:40:17
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =51, train_loss = 0.0099, train_acc = 0.9501, test_loss = 0.0119, test_acc = 0.9381, max_test_acc = 0.9393
# train speed = 3025.2767 images/s, test speed = 4915.6103 images/s
# escape time = 2024-06-13 00:39:02
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =52, train_loss = 0.0099, train_acc = 0.9503, test_loss = 0.0130, test_acc = 0.9352, max_test_acc = 0.9393
# train speed = 2486.5859 images/s, test speed = 4936.3104 images/s
# escape time = 2024-06-13 00:42:32
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =53, train_loss = 0.0100, train_acc = 0.9496, test_loss = 0.0119, test_acc = 0.9364, max_test_acc = 0.9393
# train speed = 3015.1993 images/s, test speed = 4964.0916 images/s
# escape time = 2024-06-13 00:39:08
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =54, train_loss = 0.0099, train_acc = 0.9500, test_loss = 0.0118, test_acc = 0.9396, max_test_acc = 0.9396
# train speed = 2767.7862 images/s, test speed = 5061.8328 images/s
# escape time = 2024-06-13 00:40:30
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =55, train_loss = 0.0098, train_acc = 0.9506, test_loss = 0.0119, test_acc = 0.9378, max_test_acc = 0.9396
# train speed = 3112.7261 images/s, test speed = 4940.7372 images/s
# escape time = 2024-06-13 00:38:42
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =56, train_loss = 0.0098, train_acc = 0.9509, test_loss = 0.0120, test_acc = 0.9375, max_test_acc = 0.9396
# train speed = 2798.4392 images/s, test speed = 5154.7474 images/s
# escape time = 2024-06-13 00:40:15
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =57, train_loss = 0.0098, train_acc = 0.9513, test_loss = 0.0122, test_acc = 0.9359, max_test_acc = 0.9396
# train speed = 3034.2114 images/s, test speed = 4183.8077 images/s
# escape time = 2024-06-13 00:39:22
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =58, train_loss = 0.0098, train_acc = 0.9499, test_loss = 0.0121, test_acc = 0.9353, max_test_acc = 0.9396
# train speed = 2783.0703 images/s, test speed = 5206.7930 images/s
# escape time = 2024-06-13 00:40:19
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =59, train_loss = 0.0098, train_acc = 0.9509, test_loss = 0.0124, test_acc = 0.9358, max_test_acc = 0.9396
# train speed = 2730.8518 images/s, test speed = 3467.2965 images/s
# escape time = 2024-06-13 00:41:16
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =60, train_loss = 0.0099, train_acc = 0.9508, test_loss = 0.0122, test_acc = 0.9344, max_test_acc = 0.9396
# train speed = 2961.1211 images/s, test speed = 4941.7670 images/s
# escape time = 2024-06-13 00:39:31
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =61, train_loss = 0.0098, train_acc = 0.9511, test_loss = 0.0120, test_acc = 0.9360, max_test_acc = 0.9396
# train speed = 2978.5935 images/s, test speed = 3054.9787 images/s
# escape time = 2024-06-13 00:40:16
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =62, train_loss = 0.0098, train_acc = 0.9508, test_loss = 0.0122, test_acc = 0.9361, max_test_acc = 0.9396
# train speed = 3034.9519 images/s, test speed = 4853.0312 images/s
# escape time = 2024-06-13 00:39:14
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =63, train_loss = 0.0098, train_acc = 0.9507, test_loss = 0.0123, test_acc = 0.9376, max_test_acc = 0.9396
# train speed = 2936.3928 images/s, test speed = 3003.9987 images/s
# escape time = 2024-06-13 00:40:28
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =64, train_loss = 0.0098, train_acc = 0.9508, test_loss = 0.0121, test_acc = 0.9373, max_test_acc = 0.9396
# train speed = 3046.1377 images/s, test speed = 4866.1387 images/s
# escape time = 2024-06-13 00:39:13
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =65, train_loss = 0.0098, train_acc = 0.9504, test_loss = 0.0121, test_acc = 0.9377, max_test_acc = 0.9396
# train speed = 3005.2438 images/s, test speed = 3030.9646 images/s
# escape time = 2024-06-13 00:40:08
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =66, train_loss = 0.0098, train_acc = 0.9513, test_loss = 0.0120, test_acc = 0.9354, max_test_acc = 0.9396
# train speed = 2792.4386 images/s, test speed = 5115.9257 images/s
# escape time = 2024-06-13 00:40:14
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =67, train_loss = 0.0097, train_acc = 0.9508, test_loss = 0.0122, test_acc = 0.9356, max_test_acc = 0.9396
# train speed = 2860.8390 images/s, test speed = 4660.2974 images/s
# escape time = 2024-06-13 00:40:03
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =68, train_loss = 0.0098, train_acc = 0.9505, test_loss = 0.0121, test_acc = 0.9350, max_test_acc = 0.9396
# train speed = 3083.4619 images/s, test speed = 5330.8808 images/s
# escape time = 2024-06-13 00:39:04
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =69, train_loss = 0.0097, train_acc = 0.9509, test_loss = 0.0123, test_acc = 0.9366, max_test_acc = 0.9396
# train speed = 2790.3882 images/s, test speed = 5149.6185 images/s
# escape time = 2024-06-13 00:40:12
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =70, train_loss = 0.0098, train_acc = 0.9510, test_loss = 0.0122, test_acc = 0.9370, max_test_acc = 0.9396
# train speed = 3049.2427 images/s, test speed = 5235.6868 images/s
# escape time = 2024-06-13 00:39:14
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =71, train_loss = 0.0098, train_acc = 0.9507, test_loss = 0.0125, test_acc = 0.9376, max_test_acc = 0.9396
# train speed = 2835.2268 images/s, test speed = 4996.7019 images/s
# escape time = 2024-06-13 00:40:01
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =72, train_loss = 0.0098, train_acc = 0.9509, test_loss = 0.0123, test_acc = 0.9371, max_test_acc = 0.9396
# train speed = 3014.5932 images/s, test speed = 4746.1320 images/s
# escape time = 2024-06-13 00:39:28
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =73, train_loss = 0.0097, train_acc = 0.9512, test_loss = 0.0122, test_acc = 0.9359, max_test_acc = 0.9396
# train speed = 2456.9838 images/s, test speed = 5067.9882 images/s
# escape time = 2024-06-13 00:41:31
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =74, train_loss = 0.0098, train_acc = 0.9512, test_loss = 0.0125, test_acc = 0.9341, max_test_acc = 0.9396
# train speed = 3016.2352 images/s, test speed = 4728.5417 images/s
# escape time = 2024-06-13 00:39:32
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =75, train_loss = 0.0097, train_acc = 0.9506, test_loss = 0.0122, test_acc = 0.9365, max_test_acc = 0.9396
# train speed = 2875.0964 images/s, test speed = 4617.7666 images/s
# escape time = 2024-06-13 00:39:59
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =76, train_loss = 0.0097, train_acc = 0.9509, test_loss = 0.0123, test_acc = 0.9351, max_test_acc = 0.9396
# train speed = 3029.9418 images/s, test speed = 4278.2405 images/s
# escape time = 2024-06-13 00:39:37
#
# {'T': 10, 'device': 'cuda:0', 'b': 64, 'epochs': 100, 'j': 4, 'data_dir': './datasets/MNIST', 'out_dir': './logs', 'amp': 'store_true', 'opt': 'adam', 'momentum': 0.9, 'lr': 0.001, 'tau': 2.0}
# ./logs/T10_b64_adam_lr0.001__2024-06-13-00-01_amp
# epoch =77, train_loss = 0.0097, train_acc = 0.9517, test_loss = 0.0121, test_acc = 0.9379, max_test_acc = 0.9396
# train speed = 2779.2228 images/s, test speed = 4945.6927 images/s
# escape time = 2024-06-13 00:40:12

# %% [markdown]
# * Output with Linear (100 Epochs, 100 T): 2 hrs, 19 Mins, Max Test Accuracy: 0.9293
# * Output with Quadratic (100 Epochs, 100 T): 10326.091 s (2 hrs, 52 Mins), Max Test Accuracy: 0.9445
# * Output with Linear (100 Epochs, 10 T): 28.9 Minutes, Max Test Accuracy: 0.9256
# * **Output with Quadratic (100 Epochs, 10 T): 33 Minutes, Max Test Accuracy: 0.9413**
